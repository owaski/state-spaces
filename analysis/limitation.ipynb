# %%
import sys
sys.path.append('/home/siqiouyang/work/projects/state-spaces/')

# %%
from hydra import compose, initialize
from omegaconf import OmegaConf

import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm

from src.models.sequence.model import SequenceModel
from src.tasks.encoders import PositionalEncoder

# %% [markdown]
# # Generate Dataset

# %%
class SequenceLabelDataset(Dataset):
    def __init__(self, inputs, labels):
        super(SequenceLabelDataset, self).__init__()
        assert len(inputs) == len(labels)

        self.inputs = inputs
        self.labels = labels

    def __getitem__(self, idx):
        return self.inputs[idx], self.labels[idx]

    def __len__(self):
        return len(self.inputs)

# %%
LENGTH = 10
DIM = 4
N_TRAIN = 200
N_VAL = 20
N_TEST = 20
BATCH_SIZE = 20

# %%
def get_dataset(n_sample):
    inputs = np.random.random((n_sample, LENGTH // 2, DIM))
    inputs = np.concatenate([inputs, inputs], axis=1).tolist()
    [np.random.shuffle(x) for x in inputs]
    inputs = torch.tensor(inputs)

    labels = []
    for x in inputs:
        label = []
        for i in range(len(x)):
            flag = True
            for j in range(i):
                if x[i].equal(x[j]):
                    flag = False
            label.append(0 if flag else 1)
        labels.append(label)
    labels = torch.tensor(labels)

    dataset = SequenceLabelDataset(inputs, labels)
    return dataset

# %%
train_ds = get_dataset(N_TRAIN)
val_ds = get_dataset(N_VAL)
test_ds = get_dataset(N_TEST)

# %%
train_dataloader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# # Build Model

# %%
class Classifier(nn.Module):
    def __init__(self, model):
        super(Classifier, self).__init__()
        self.model = model
        self.proj = nn.Linear(DIM, 2)

    def forward(self, x):
        x = self.model(x)
        if type(x) is tuple:
            x = x[0]
        return self.proj(x)

# %%
initialize(version_base=None, config_path='../configs/model/')
# Out:
# hydra.initialize()

# %%
cfg = compose(config_name='s4_dev')
OmegaConf.set_struct(cfg, False)
cfg.pop('_name_'), cfg.pop('encoder'), cfg.pop('decoder')
s4 = SequenceModel(**cfg)
# Out:
# CUDA extension for Cauchy multiplication not found. Install by going to extensions/cauchy/ and running `python setup.py install`. This should speed up end-to-end training by 10-50%

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, d_model, d_hidden, n_head, n_layer, batch_first=True, norm_first=True):
        super(TransformerEncoder, self).__init__()

        self.position_emb = PositionalEncoder(d_model=d_model, dropout=0., max_len=LENGTH)
        layer = nn.TransformerEncoderLayer(d_model, n_head, d_hidden, dropout=0., batch_first=batch_first, norm_first=norm_first)
        layer_norm = nn.LayerNorm(d_model)
        self.encoder = nn.TransformerEncoder(layer, n_layer, norm=layer_norm)

    def forward(self, x):
        x = self.position_emb(x)
        return self.encoder(x)

# %%
transformer = TransformerEncoder(DIM, DIM * 4, 1, 1)

# %%
clas_s4 = Classifier(s4)
clas_xfm = Classifier(transformer)

# %%
model = clas_s4
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.CrossEntropyLoss()

# %%
running_loss = 0.
running_acc = 0.
n_epoch = 10
for _ in range(n_epoch):
    iterator = tqdm(train_dataloader)
    for inputs, labels in iterator:
        model.zero_grad()
        preds = model(inputs)
        loss = loss_fn(preds.transpose(1, 2), labels)
        loss.backward()

        print('\n', '=' * 10)
        for name, param in model.named_parameters():
            print(name, param.grad)
        print('\n', '=' * 10)

        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        running_loss = 0.1 * loss.item() + 0.9 * running_loss

        acc = (preds.argmax(dim=-1) == labels).float().mean()
        running_acc = 0.1 * acc.item() + 0.9 * running_acc

        # iterator.set_description('running loss {:.2f} running acc {:.2f}'.format(running_loss, running_acc))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[  1.9214,   7.6651],
#           [ -5.8614,   0.0721]],
#
#          [[-10.6703,  -8.0080],
#           [  4.7503,  -4.3997]],
#
#          [[  3.1856,  -4.0136],
#           [  0.8359,   4.6546]],
#
#          [[ -0.4345,   0.8220],
#           [  1.2137,  -0.2218]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([-9.5746, 17.7018,  2.0300,  0.4894])
# model.layers.0.layer.kernel.kernel.B tensor([[[[ 8.6189,  4.0891],
#           [ 0.5126, -4.1888]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[-15.1971,  -0.8256],
#           [ 11.1049,   5.5160]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[2.2841, 5.1299]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[-2.3956, -3.5007]])
# model.layers.0.layer.output_linear.0.weight tensor([[-0.0037,  0.0259,  0.0108,  0.0061],
#         [ 0.0155, -0.0651, -0.0258, -0.0702],
#         [-0.0142, -0.0128, -0.0141,  0.0070],
#         [ 0.0038,  0.0352,  0.0203,  0.0400],
#         [ 0.0027, -0.0055,  0.0006, -0.0022],
#         [ 0.0010,  0.0111, -0.0014,  0.0104],
#         [-0.0022, -0.0035, -0.0009, -0.0024],
#         [-0.0002, -0.0157, -0.0017, -0.0167]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0149, -0.0890, -0.0099,  0.0593, -0.0019,  0.0104, -0.0056, -0.0193])
# model.layers.0.norm.norm.weight tensor([-8.9308, 10.2012, -6.0238, 12.0039])
# model.layers.0.norm.norm.bias tensor([142.2575, 116.4574,  49.5387,  77.2989])
# model.norm.norm.weight tensor([0.0022, 0.0565, 0.0015, 0.0081])
# model.norm.norm.bias tensor([ 0.0022, -0.0121,  0.0007,  0.0053])
# proj.weight tensor([[-0.0226,  0.1050, -0.0479, -0.0343],
#         [ 0.0226, -0.1050,  0.0479,  0.0343]])
# proj.bias tensor([-0.0225,  0.0225])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[ 1.9093e+00, -3.9229e+00],
#           [-1.6585e+00,  7.1105e-01]],
#
#          [[-1.8653e-01,  2.8685e-02],
#           [ 4.4860e-02, -1.0331e-01]],
#
#          [[ 5.0711e+00, -3.3417e+00],
#           [-2.6353e+00,  2.1332e+00]],
#
#          [[ 1.1755e-02, -1.2847e-03],
#           [-2.2020e-02,  3.0855e-04]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([ 1.5493,  0.1655, -0.1326,  0.0021])
# model.layers.0.layer.kernel.kernel.B tensor([[[[ 1.0100, -0.9518],
#           [-3.9218, -0.7950]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[-1.2143,  0.7974],
#           [ 4.1608,  0.6182]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[0.0107, 0.7273]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[-0.1801, -0.7537]])
# model.layers.0.layer.output_linear.0.weight tensor([[-6.0260e-03,  3.9109e-03,  1.1407e-02,  4.6950e-03],
#         [ 1.0342e-02,  7.3028e-03, -3.1266e-02, -4.8588e-02],
#         [-1.6434e-02, -4.2187e-03, -5.5163e-03,  2.3891e-02],
#         [ 1.8765e-02, -7.9568e-03,  1.7860e-02,  1.0509e-02],
#         [ 3.9467e-03, -7.9718e-04,  2.8215e-05,  3.8734e-04],
#         [ 6.6115e-03, -6.4015e-03,  2.5428e-04, -1.1858e-03],
#         [-3.6554e-03, -8.3943e-04,  4.2261e-04, -4.0828e-03],
#         [-4.7883e-03,  5.3808e-03, -3.4675e-03, -1.3399e-03]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0114, -0.0457, -0.0042,  0.0267,  0.0009, -0.0036, -0.0040, -0.0042])
# model.layers.0.norm.norm.weight tensor([-7.9557,  0.0405, -7.8323,  0.0180])
# model.layers.0.norm.norm.bias tensor([-8.0323, -0.0186, -9.3490,  0.0673])
# model.norm.norm.weight tensor([0.0024, 0.0467, 0.0003, 0.0121])
# model.norm.norm.bias tensor([-1.7083e-04,  9.4585e-04, -5.3499e-05, -4.1236e-04])
# proj.weight tensor([[-0.0252,  0.0869, -0.0102, -0.0516],
#         [ 0.0252, -0.0869,  0.0102,  0.0516]])
# proj.bias tensor([ 0.0018, -0.0018])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[-2.0170e-04,  1.2839e-04],
#           [-7.2095e-04,  1.5037e-04]],
#
#          [[-6.3095e-02,  3.3793e-02],
#           [ 1.5560e-02, -1.0710e-02]],
#
#          [[ 6.0802e+00, -3.9834e+00],
#           [-3.1424e+00,  2.5558e+00]],
#
#          [[-1.3332e-03,  2.9263e-04],
#           [ 3.4124e-03, -9.7737e-05]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([-0.0003, -0.0066, -0.1543,  0.0004])
# model.layers.0.layer.kernel.kernel.B tensor([[[[0.6542, 0.8538],
#           [1.5842, 0.2773]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[-0.7899, -0.8148],
#           [-0.9467, -0.0235]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[ 0.1135, -0.0787]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[-0.0800, -0.0744]])
# model.layers.0.layer.output_linear.0.weight tensor([[-0.0091,  0.0012,  0.0107,  0.0203],
#         [ 0.0241, -0.0116, -0.0162, -0.0516],
#         [-0.0255, -0.0064, -0.0079,  0.0034],
#         [ 0.0137,  0.0100,  0.0082,  0.0138],
#         [ 0.0053,  0.0020,  0.0002, -0.0003],
#         [ 0.0024, -0.0024,  0.0014,  0.0020],
#         [-0.0035, -0.0018, -0.0003, -0.0010],
#         [-0.0032, -0.0024, -0.0012, -0.0062]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0189, -0.0503, -0.0130,  0.0304,  0.0016,  0.0029, -0.0033, -0.0087])
# model.layers.0.norm.norm.weight tensor([-1.8251e-03,  2.8331e-03, -9.3633e+00,  1.5296e-02])
# model.layers.0.norm.norm.bias tensor([-2.1903e-02,  2.0894e-02, -9.3495e+00,  7.6864e-03])
# model.norm.norm.weight tensor([0.0029, 0.0514, 0.0002, 0.0140])
# model.norm.norm.bias tensor([ 0.0016, -0.0089,  0.0005,  0.0039])
# proj.weight tensor([[-0.0298,  0.0957, -0.0058, -0.0599],
#         [ 0.0298, -0.0957,  0.0058,  0.0599]])
# proj.bias tensor([-0.0166,  0.0166])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[  6.5781,   6.8583],
#           [-13.5335,   0.6873]],
#
#          [[ -0.5705,  11.7746],
#           [ -6.3873,  -0.7913]],
#
#          [[-20.0676,  12.8813],
#           [  5.0764,  -1.3774]],
#
#          [[ -2.3421,  -1.1126],
#           [  4.8505,   0.2743]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([-10.6839,  -8.2036,   3.6636,  -0.6461])
# model.layers.0.layer.kernel.kernel.B tensor([[[[ 24.7945,  -4.8723],
#           [-47.4857, -15.3165]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[-28.2312,   3.0907],
#           [ 55.9492,   9.6098]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[ 3.6526, 14.2077]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[ 3.4425, -5.4236]])
# model.layers.0.layer.output_linear.0.weight tensor([[-0.0100, -0.0014,  0.0151,  0.0021],
#         [ 0.0317, -0.0089, -0.0391, -0.0338],
#         [-0.0199,  0.0005, -0.0153,  0.0034],
#         [ 0.0055,  0.0067,  0.0262,  0.0190],
#         [ 0.0043, -0.0003,  0.0019,  0.0004],
#         [ 0.0050,  0.0026, -0.0023,  0.0023],
#         [-0.0028, -0.0011, -0.0017, -0.0021],
#         [-0.0022, -0.0038, -0.0011, -0.0060]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0069, -0.0478, -0.0056,  0.0329,  0.0029,  0.0024, -0.0039, -0.0066])
# model.layers.0.norm.norm.weight tensor([-27.4447, -12.1157,  26.9088,   0.9818])
# model.layers.0.norm.norm.bias tensor([177.0113, 115.7482,  63.8782,  64.1470])
# model.norm.norm.weight tensor([0.0025, 0.0600, 0.0011, 0.0116])
# model.norm.norm.bias tensor([ 0.0004, -0.0024,  0.0001,  0.0010])
# proj.weight tensor([[-0.0260,  0.1118, -0.0362, -0.0495],
#         [ 0.0260, -0.1118,  0.0362,  0.0495]])
# proj.bias tensor([-0.0045,  0.0045])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[ 1.6809e-03,  1.3213e-03],
#           [-4.2773e-04,  2.3980e-04]],
#
#          [[-7.3188e-02,  2.4949e-02],
#           [ 1.5417e-02, -2.3078e-02]],
#
#          [[-2.3715e-03, -1.6319e-04],
#           [ 2.3063e-04, -1.9347e-04]],
#
#          [[-9.5093e-05,  1.8882e-03],
#           [-1.9104e-04, -4.8778e-04]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([-3.3921e-03,  2.0721e-02, -4.2580e-05,  5.2316e-04])
# model.layers.0.layer.kernel.kernel.B tensor([[[[ 0.0190,  0.0306],
#           [ 0.0590, -0.0047]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[-0.0367, -0.0284],
#           [-0.0376,  0.0104]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[0.0064, 0.0041]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[-0.0073, -0.0022]])
# model.layers.0.layer.output_linear.0.weight tensor([[-1.0310e-02,  4.8310e-03,  9.9724e-03,  1.6331e-02],
#         [ 2.7921e-02,  1.6547e-04, -2.3858e-02, -3.1447e-02],
#         [-1.1531e-02, -7.4655e-03, -1.4729e-02, -5.4840e-03],
#         [ 1.2785e-03,  1.7119e-03,  2.0271e-02,  1.2368e-02],
#         [ 4.6135e-03, -2.6482e-04,  4.5256e-04, -1.3282e-03],
#         [ 2.7959e-03, -5.7829e-04, -7.0349e-04, -5.6356e-06],
#         [-2.4969e-03, -1.4669e-03, -2.2138e-04, -1.4067e-03],
#         [-5.2886e-04,  3.7467e-04, -2.4953e-03, -2.2534e-03]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0122, -0.0294, -0.0150,  0.0227,  0.0017,  0.0010, -0.0030, -0.0041])
# model.layers.0.norm.norm.weight tensor([-0.0009,  0.0061,  0.0023,  0.0096])
# model.layers.0.norm.norm.bias tensor([-0.0173,  0.0050,  0.0013,  0.0115])
# model.norm.norm.weight tensor([0.0025, 0.0574, 0.0010, 0.0106])
# model.norm.norm.bias tensor([ 0.0028, -0.0156,  0.0009,  0.0068])
# proj.weight tensor([[-0.0258,  0.1069, -0.0354, -0.0454],
#         [ 0.0258, -0.1069,  0.0354,  0.0454]])
# proj.bias tensor([-0.0292,  0.0292])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[-9.5281,  5.6926],
#           [ 7.8345, -1.2324]],
#
#          [[ 1.2904, -2.5203],
#           [ 4.5244, -4.7985]],
#
#          [[-6.5323, 11.7162],
#           [-1.7071,  2.3212]],
#
#          [[-1.7056, -0.0902],
#           [ 3.5515,  0.0300]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([ 0.9165, 10.3232,  6.2910, -0.2489])
# model.layers.0.layer.kernel.kernel.B tensor([[[[-11.6410,   6.3918],
#           [ 32.5472,  10.0687]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[ 13.7263,   1.7392],
#           [-29.4939,  -8.6444]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[-0.9610, -5.3210]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[-4.5739,  0.6549]])
# model.layers.0.layer.output_linear.0.weight tensor([[-1.3922e-02,  6.2675e-03,  9.3863e-03, -9.9034e-03],
#         [ 2.8700e-02,  1.2044e-02, -6.6672e-03,  2.1752e-02],
#         [-2.1578e-02, -1.3301e-02, -1.9817e-02, -2.3283e-02],
#         [ 1.2830e-02, -2.5653e-03,  1.4471e-02,  1.6413e-02],
#         [ 5.3047e-03, -1.1214e-03, -3.2277e-05,  1.9803e-03],
#         [ 6.8919e-03, -4.8038e-03,  1.8949e-03,  6.3489e-04],
#         [-3.1767e-03, -2.3199e-03,  7.4552e-04, -2.1282e-04],
#         [-2.9611e-03,  2.5584e-03, -2.5105e-03, -4.4365e-03]])
# model.layers.0.layer.output_linear.0.bias tensor([-0.0016,  0.0321, -0.0471,  0.0222,  0.0024, -0.0025, -0.0013, -0.0047])
# model.layers.0.norm.norm.weight tensor([26.5691,  8.9340, 10.4896, -6.0158])
# model.layers.0.norm.norm.bias tensor([146.8832, 115.8080,  77.7370,  87.8657])
# model.norm.norm.weight tensor([0.0037, 0.0569, 0.0002, 0.0136])
# model.norm.norm.bias tensor([-0.0006,  0.0032, -0.0002, -0.0014])
# proj.weight tensor([[-0.0392,  0.1063, -0.0088, -0.0584],
#         [ 0.0392, -0.1063,  0.0088,  0.0584]])
# proj.bias tensor([ 0.0059, -0.0059])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[-6.0415e-05, -1.0792e-04],
#           [-1.7347e-03, -1.6606e-04]],
#
#          [[-5.1404e-02,  3.0869e-02],
#           [ 1.8570e-02, -1.4525e-02]],
#
#          [[-1.0499e-03,  1.0438e-03],
#           [ 8.2447e-04, -3.6491e-04]],
#
#          [[ 4.9380e-06,  9.4301e-04],
#           [ 1.3494e-04, -2.4812e-04]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([ 1.5851e-03, -5.0244e-03,  8.4367e-05,  4.6652e-04])
# model.layers.0.layer.kernel.kernel.B tensor([[[[ 0.0145,  0.0239],
#           [ 0.0479, -0.0039]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[-0.0241, -0.0269],
#           [-0.0370,  0.0038]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[ 0.0044, -0.0009]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[-0.0024, -0.0029]])
# model.layers.0.layer.output_linear.0.weight tensor([[-0.0078,  0.0105,  0.0130,  0.0063],
#         [ 0.0233,  0.0130, -0.0288,  0.0201],
#         [-0.0240, -0.0272, -0.0082, -0.0303],
#         [ 0.0136,  0.0072,  0.0146,  0.0123],
#         [ 0.0038, -0.0027,  0.0006, -0.0007],
#         [ 0.0074, -0.0024,  0.0008, -0.0015],
#         [-0.0037, -0.0015, -0.0016,  0.0014],
#         [-0.0042, -0.0034, -0.0006, -0.0048]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0067, -0.0043, -0.0309,  0.0288,  0.0013,  0.0002, -0.0024, -0.0070])
# model.layers.0.norm.norm.weight tensor([-0.0035,  0.0091,  0.0018,  0.0073])
# model.layers.0.norm.norm.bias tensor([-0.0233,  0.0276,  0.0006,  0.0059])
# model.norm.norm.weight tensor([0.0032, 0.0590, 0.0008, 0.0105])
# model.norm.norm.bias tensor([ 0.0004, -0.0022,  0.0001,  0.0009])
# proj.weight tensor([[-0.0341,  0.1103, -0.0309, -0.0453],
#         [ 0.0341, -0.1103,  0.0309,  0.0453]])
# proj.bias tensor([-0.0041,  0.0041])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[    nan,     nan],
#           [    nan,     nan]],
#
#          [[ 1.4640,  0.4632],
#           [-3.1449, -0.5345]],
#
#          [[    nan,     nan],
#           [    nan,     nan]],
#
#          [[ 0.1889,  1.3085],
#           [ 0.1731, -0.3422]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([    nan, -0.1912,     nan,  0.8582])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[-0.0136,  0.0031,  0.0096,  0.0079],
#         [ 0.0308,  0.0203, -0.0283, -0.0358],
#         [-0.0202, -0.0136, -0.0031,  0.0067],
#         [ 0.0110, -0.0100,  0.0147,  0.0132],
#         [ 0.0058,  0.0001,  0.0004,  0.0008],
#         [ 0.0044, -0.0072,  0.0010, -0.0009],
#         [-0.0030, -0.0042, -0.0003, -0.0015],
#         [-0.0025,  0.0046, -0.0022, -0.0029]])
# model.layers.0.layer.output_linear.0.bias tensor([ 0.0073, -0.0383, -0.0114,  0.0328,  0.0025, -0.0020, -0.0036, -0.0058])
# model.layers.0.norm.norm.weight tensor([ 1.4614e+37, -4.3385e+00, -1.1994e+37,  1.2115e+01])
# model.layers.0.norm.norm.bias tensor([ 3.8142e+37, -8.1851e+00,  1.8701e+37,  4.3763e+00])
# model.norm.norm.weight tensor([ 0.0049,  0.0486, -0.0004,  0.0122])
# model.norm.norm.bias tensor([ 0.0005, -0.0029,  0.0001,  0.0013])
# proj.weight tensor([[-0.0527,  0.0911,  0.0145, -0.0527],
#         [ 0.0527, -0.0911, -0.0145,  0.0527]])
# proj.bias tensor([-0.0055,  0.0055])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#   0%|          | 0/10 [00:00<?, ?it/s]
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#   0%|          | 0/10 [00:00<?, ?it/s]
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#   0%|          | 0/10 [00:00<?, ?it/s]
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# ...
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#   0%|          | 0/10 [00:00<?, ?it/s]
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========
#
#  ==========
# model.layers.0.layer.kernel.kernel.C tensor([[[[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]],
#
#          [[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.log_dt tensor([nan, nan, nan, nan])
# model.layers.0.layer.kernel.kernel.B tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.P tensor([[[[nan, nan],
#           [nan, nan]]]])
# model.layers.0.layer.kernel.kernel.inv_w_real tensor([[nan, nan]])
# model.layers.0.layer.kernel.kernel.w_imag tensor([[nan, nan]])
# model.layers.0.layer.output_linear.0.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# model.layers.0.layer.output_linear.0.bias tensor([nan, nan, nan, nan, nan, nan, nan, nan])
# model.layers.0.norm.norm.weight tensor([nan, nan, nan, nan])
# model.layers.0.norm.norm.bias tensor([nan, nan, nan, nan])
# model.norm.norm.weight tensor([nan, nan, nan, nan])
# model.norm.norm.bias tensor([nan, nan, nan, nan])
# proj.weight tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan]])
# proj.bias tensor([nan, nan])
#
#  ==========

# %%
preds = model(inputs)
loss = loss_fn(preds.transpose(1, 2), labels)

# %%
print(loss)
# Out:
# tensor(0.7652, grad_fn=<NllLoss2DBackward0>)
